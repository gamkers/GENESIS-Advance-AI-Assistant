# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
import requests
from bs4 import BeautifulSoup
def movie():
    data={}
    # Specify the URL of the webpage you want to scrape
    url = "https://in.bookmyshow.com/buytickets/leo-chennai/movie-chen-ET00351731-MT/20231020"

    # Specify the path to the chromedriver executable
    chrome_path = "C:/chromedriver.exe"

    # Set up the Chrome driver with necessary options
    options = webdriver.ChromeOptions()
    options.add_argument("--disable-blink-features=AutomationControlled")
    service = Service(chrome_path)
    driver = webdriver.Chrome(service=service, options=options)

    # Go to the URL
    driver.get(url)

    # Add code to solve the Cloudflare challenge here if necessary

    # Get the HTML content of the webpage
    html = driver.page_source

    print(html)
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')

    # Find all elements with the specified tag and class
    venue_names = soup.find_all('a', class_='__venue-name')

    # Print the text content of the elements
    for venue in venue_names:
        href = venue.get('href')
        data[venue.text]=href

    # Close the browser window
    driver.quit()
    return data

# %%
data
# Out:
# {'AGS Cinemas OMR: Navlur': '/buytickets/ags-cinemas-omr-navlur/cinema-chen-ACON-MT/20231020',
#  'AGS Cinemas: Maduravoyal': '/buytickets/ags-cinemas-maduravoyal/cinema-chen-AGSM-MT/20231020',
#  'AGS Cinemas: T. Nagar': '/buytickets/ags-cinemas-t-nagar/cinema-chen-ACTN-MT/20231020',
#  'AGS Cinemas: Villivakkam': '/buytickets/ags-cinemas-villivakkam/cinema-chen-ACVM-MT/20231020',
#  'Anand Theatre Madhuranthagam RGB LASER 4k': '/buytickets/anand-theatre-madhuranthagam-rgb-laser-4k/cinema-chen-ATMG-MT/20231020',
#  'Anna Cinemas: Mount Road': '/buytickets/anna-cinemas-mount-road/cinema-chen-ANAC-MT/20231020',
#  'Arul Muruga Theatre 4K: Thiruporur': '/buytickets/arul-muruga-theatre-4k-thiruporur/cinema-chen-AMTT-MT/20231020',
#  'BG Parimalam Cinemas (Silver Screen): Kundrathur': '/buytickets/bg-parimalam-cinemas-silver-screen-kundrathur/cinema-chen-RACS-MT/20231020',
# ...

# %%
def movietime(data,name):

    for theatre,link in data.items():
        if name in link:
            print(link)
            # Go to the URL
            # Specify the path to the chromedriver executable
            chrome_path = "C:/chromedriver.exe"
            # Set up the Chrome driver with necessary options
            options = webdriver.ChromeOptions()
            options.add_argument("--disable-blink-features=AutomationControlled")
            service = Service(chrome_path)
            driver = webdriver.Chrome(service=service, options=options)

            driver.get(f"https://in.bookmyshow.com{link}")
            # Add code to solve the Cloudflare challenge here if necessary
            # Get the HTML content of the webpage
            html1 = driver.page_source
            # Close the browser window
            driver.quit()
            soup = BeautifulSoup(html1, 'html.parser')
            elements = soup.find_all('div', attrs={'data-online': 'Y'})
            talk("The shows are available at")
            for element in elements:
                text_element = element.find('div', class_='__text')
                if text_element:
                    talk(text_element.get_text(strip=True))
            talk("Did you want to book the tickets?")
            cmd=take_command()
            if "yes" in cmd:
                import webbrowser
                webbrowser.open(f"https://in.bookmyshow.com{link}")

# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        import pyttsx3
from pyttsx3 import Engine
engine: Engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)
engine.setProperty('rate', 160)
engine.runAndWait()
def talk(text):
    engine.say(text)
    print(text)
    engine.runAndWait()

# %%
from pyttsx3 import Engine
import speech_recognition as sr
import pyttsx3
import pygame
from time import sleep
import datetime

listener = sr.Recognizer()
engine: Engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)
engine.setProperty('rate', 171)
engine.setProperty('volume', 150)
engine.runAndWait()
# Out:
# pygame 2.5.2 (SDL 2.28.3, Python 3.9.13)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
def take_command():
    r = sr.Recognizer()

    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source, 0, 4)

    try:
        print("Recognizing..")
        query = r.recognize_google(audio, language="en-in")
        print(f"You Said : {query}")
        return query

    except:
        return ""

    query = str(query)
    return query.lower()

# %%
def main(data):
    while True:
        command = take_command()
        if "hi" in command:
            talk("Hello")
        elif "ticket" in command:
            talk("which theatre would you prefer, sir?")
            name = "phoenix"
            movietime(data,name)

# %%
main(data)
# Out:
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# You Said : Jarvis book a ticket for a new
# which theatre would you prefer, sir?
# /buytickets/inox-luxe-phoenix-market-city-velachery/cinema-chen-INPR-MT/20231020
# The shows are available at
# 04:05 PM
# 04:25 PM
# 04:40 PM
# 06:10 PM
# 07:10 PM
# 07:40 PM
# 10:10 PM
# 10:25 PM
# Did you want to book the tickets?
# Listening...
# Recognizing..
# You Said : yes please
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# Listening...
# Recognizing..
# ...
